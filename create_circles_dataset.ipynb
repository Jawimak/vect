# %%
# генерация с параметрами

import os, random
from PIL import Image, ImageDraw
import json

def generate_circle_dataset(out_dir, n_samples=5000, img_size=224, min_r=10, max_r=80):
    os.makedirs(out_dir, exist_ok=True)
    meta = []
    for i in range(n_samples):
        width = height = img_size
        # параметры
        r = random.randint(min_r, max_r)
        x = random.randint(r, img_size - r)
        y = random.randint(r, img_size - r)


        svg_content = f'''<?xml version="1.0" encoding="utf-8"?>
<svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
    width="{width}px" height="{height}px" viewBox="0 0 {width} {height}" style="enable-background:new 0 0 {width} {height};" xml:space="preserve">
    <rect width="{width}" height="{height}" fill="white"/>
    <g>
        <circle cx="{x}" cy="{y}" r="{r}" fill="black"/>
    </g>
</svg>'''
        # рисуем
        im = Image.new("RGB", (img_size, img_size), "white")
        draw = ImageDraw.Draw(im)
        draw.ellipse((x-r, y-r, x+r, y+r), fill="black")
        pngname = f"{i:05d}.png"
        im.save(os.path.join(out_dir, "png/", f"{i:05d}.png"))
        with open(os.path.join(out_dir, "svg/" f"{i:05d}.svg"), 'w') as file:
            file.write(svg_content) 
        meta.append((pngname, x, y, r))
    # сохраняем метаданные
    with open(os.path.join(out_dir, "labels.json"), "w") as f:
        json.dump(meta, f)

# %%
# генерация со строкой

import os, random
from PIL import Image, ImageDraw
import json

def generate_circle_dataset(out_dir, n_samples=5000, img_size=224, min_r=10, max_r=80):
    os.makedirs(out_dir, exist_ok=True)
    meta = []
    for i in range(n_samples):
        width = height = img_size
        # параметры
        r = random.randint(min_r, max_r)
        x = random.randint(r, img_size - r)
        y = random.randint(r, img_size - r)

        circle_content = f'''<circle cx="{x}" cy="{y}" r="{r}" fill="black"/>'''

        svg_content = f'''<?xml version="1.0" encoding="utf-8"?>
<svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
    width="{width}px" height="{height}px" viewBox="0 0 {width} {height}" style="enable-background:new 0 0 {width} {height};" xml:space="preserve">
    <rect width="{width}" height="{height}" fill="white"/>
    <g>
        {circle_content}
    </g>
</svg>'''
        # рисуем
        im = Image.new("RGB", (img_size, img_size), "white")
        draw = ImageDraw.Draw(im)
        draw.ellipse((x-r, y-r, x+r, y+r), fill="black")
        pngname = f"{i:05d}.png"
        im.save(os.path.join(out_dir, "png/", f"{i:05d}.png"))
        with open(os.path.join(out_dir, "svg/" f"{i:05d}.svg"), 'w') as file:
            file.write(svg_content) 
        meta.append((pngname, circle_content))
    # сохраняем метаданные
    with open(os.path.join(out_dir, "png/labels.json"), "w") as f:
        json.dump(meta, f)

# %%
generate_circle_dataset("../datasets/circles_str", n_samples=5000)

# %%
# генерация со строкой на несколько окружностей

import os, random
from PIL import Image, ImageDraw
import json

def generate_random_hex():
    return ''.join(random.choice('0123456789ABCDEF') for _ in range(6))

def generate_circle_dataset(out_dir, n_samples=5000, img_size=224, min_r=10, max_r=80, max_n = 1, min_n = 1):
    os.makedirs(out_dir, exist_ok=True)
    meta = []
    for i in range(n_samples):
        im = Image.new("RGB", (img_size, img_size), "white")
        draw = ImageDraw.Draw(im)
        width = height = img_size
        svg_content = f'''<?xml version="1.0" encoding="utf-8"?>
<svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
    width="{width}px" height="{height}px" viewBox="0 0 {width} {height}" style="enable-background:new 0 0 {width} {height};" xml:space="preserve">
    <rect width="{width}" height="{height}" fill="white"/>
    <g>'''
        circles_num = random.randint(min_n, max_n)
        for j in range(circles_num):

            r = random.randint(min_r, max_r)
            x = random.randint(r, img_size - r)
            y = random.randint(r, img_size - r)
            color = generate_random_hex()
            
            draw.ellipse((x-r, y-r, x+r, y+r), fill=f"#{color}")

            circle_content = f'''<circle cx="{x}" cy="{y}" r="{r}" fill="#{color}"/>'''

        
            add_content = f'''
        {circle_content}'''
            svg_content += add_content
        end_content = '''
    </g>
</svg>'''
        svg_content += end_content

        pngname = f"{i:05d}.png"
        im.save(os.path.join(out_dir, "png/", f"{i:05d}.png"))
        with open(os.path.join(out_dir, "svg/" f"{i:05d}.svg"), 'w') as file:
            file.write(svg_content) 
        meta.append((pngname, circle_content))
    # сохраняем метаданные
    with open(os.path.join(out_dir, "png/labels.json"), "w") as f:
        json.dump(meta, f)

# %%
generate_circle_dataset("../datasets/n_circles", n_samples=5000, max_n = 5)

# %%
# генерация с квадратами

import os, random
from PIL import Image, ImageDraw
import json


def generate_random_hex():
    return ''.join(random.choice('0123456789ABCDEF') for _ in range(6))


def generate_rect_dataset(out_dir, n_samples=5000, img_size=224, min_r=10, max_r=80, max_n = 1, min_n = 1):

    os.makedirs(out_dir, exist_ok=True)
    meta = []
    for i in range(n_samples):
        im = Image.new("RGB", (img_size, img_size), "white")
        draw = ImageDraw.Draw(im)
        width = height = img_size
        svg_content = f'''<?xml version="1.0" encoding="utf-8"?>
<svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
    width="{width}px" height="{height}px" viewBox="0 0 {width} {height}" style="enable-background:new 0 0 {width} {height};" xml:space="preserve">
    <rect width="{width}" height="{height}" fill="white"/>
    <g>'''
        for l in range(max_n):
            figure_type = random.randint(0, 1)
            if figure_type == 0:
                r = random.randint(min_r, max_r)
                x = random.randint(r, img_size - r)
                y = random.randint(r, img_size - r)
                color = generate_random_hex()
                
                draw.ellipse((x-r, y-r, x+r, y+r), fill=f"#{color}")

                circle_content = f'''<circle cx="{x}" cy="{y}" r="{r}" fill="#{color}"/>'''

                add_content = f'''
        {circle_content}'''
                svg_content += add_content

            elif figure_type == 1:
                r = random.randint(min_r, max_r)
                x = random.randint(r, img_size - r)
                y = random.randint(r, img_size - r)

                color = generate_random_hex()

                draw.rectangle((x-r, y-r, x+r, y+r), fill=f"#{color}")

                rect_content = f'''<rect x="{x}" y="{y}" width="{r}" height="{r}" fill="#{color}/>'''
                add_content = f'''
        {rect_content}'''

        end_content = '''
    </g>
</svg>'''
        svg_content += end_content

        pngname = f"{i:05d}.png"
        im.save(os.path.join(out_dir, "png/", f"{i:05d}.png"))
        with open(os.path.join(out_dir, "svg/" f"{i:05d}.svg"), 'w') as file:
            file.write(svg_content) 
        meta.append((pngname, circle_content))
    # сохраняем метаданные
    with open(os.path.join(out_dir, "png/labels.json"), "w") as f:
        json.dump(meta, f)

# %%
generate_rect_dataset("../datasets/circles_and_rect", n_samples=5000, max_n = 5)

# %%
import os
from PIL import Image
import numpy as np
import cairosvg

def compare_images(img1_path, img2_path):
    # Open images
    img1 = Image.open(img1_path)
    img2 = Image.open(img2_path)
    
    # Resize images to the same size
    img1 = img1.resize((224, 224))
    img2 = img2.resize((224, 224))
    
    arr1 = np.array(img1)
    arr2 = np.array(img2)

    difference = np.abs(arr1.astype(np.float32) - arr2.astype(np.float32))

    mse = np.mean(difference ** 2)
    max_pixel_value = 255.0
    percent_difference = (mse / (max_pixel_value ** 2)) * 100
    return percent_difference <= 5.0

folder1 = '../datasets/circles_str/png/'
folder2 = '../datasets/circles_str/pngg/'
equal = not_equal = 0
for i in range(5000):
    img1_path = os.path.join(folder1, f'{i:05d}.png')
    img2_path = os.path.join(folder2, f'{i:05d}.png')
    if os.path.exists(img1_path) and os.path.exists(img2_path):
        if compare_images(img1_path, img2_path):
            equal += 1
        else:
            not_equal += 1
    else:
        print(f'Одно из изображений {i:05d} отсутствует.')

print(f"совпадает: {equal} изображений")
print(f"не совпадает: {not_equal} изображений")
print(f"совпадает: {equal/(equal+not_equal)} процентов изображений")
# Out:
# совпадает: 5000 изображений
# не совпадает: 0 изображений
# совпадает: 1.0 процентов изображений

# %%
for i in range(5000):
    svg_file = os.path.join('../datasets/circles/svg/', f'{i:05d}.svg')
    png_file = os.path.join('../datasets/circles/pngg/', f'{i:05d}.png')
    # Convert SVG to PNG
    try:
        cairosvg.svg2png(url=svg_file, write_to=png_file)
    except Exception as e:
        print(f"Error converting {svg_file}: {e}")
        continue  # Skip to the next iteration if there's an error
    # Open the PNG file with Pillow
    try:
        with Image.open(png_file) as image:
            # Create a new image with a white background
            background = Image.new('RGB', image.size, (255, 255, 255))
            # Paste the original image on top of the background
            background.paste(image.convert('RGBA'), (0, 0), image.convert('RGBA'))
            # Save the final image
            background.save(png_file)
    except Exception as e:
        print(f"Error processing {png_file}: {e}")

# %%
import cairosvg
def convert_svg_to_png(svg_folder, png_folder, num_images=5000):
    os.makedirs(png_folder, exist_ok=True)
    for i in range(num_images):
        svg_file = os.path.join(svg_folder, f'{i:05d}.svg')
        png_file = os.path.join(png_folder, f'{i:05d}.png')
        
        try:
            cairosvg.svg2png(url=svg_file, write_to=png_file)
            with Image.open(png_file) as image:
                background = Image.new('RGB', image.size, (255, 255, 255))
                background.paste(image, (0, 0), image)
                background.save(png_file)
        except Exception as e:
            print(f'Error processing {svg_file}: {e}')

# %%
svg_folder = '../datasets/circles_str/svg/'
png_folder = '../datasets/circles_str/pngg/'
convert_svg_to_png(svg_folder, png_folder)
# Out:
# Error processing ../datasets/circles_str/svg/00000.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00001.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00002.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00003.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00004.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00005.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00006.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00007.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00008.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00009.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00010.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00011.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00012.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00013.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00014.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00015.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00016.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00017.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00018.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00019.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00020.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00021.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00022.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00023.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00024.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00025.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00026.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00027.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00028.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00029.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00030.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00031.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00032.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00033.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00034.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00035.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00036.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00037.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00038.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00039.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00040.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00041.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00042.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00043.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00044.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00045.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00046.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00047.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00048.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00049.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00050.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00051.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00052.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00053.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00054.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00055.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00056.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00057.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00058.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00059.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00060.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00061.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00062.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00063.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00064.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00065.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00066.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00067.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00068.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00069.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00070.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00071.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00072.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00073.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00074.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00075.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00076.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00077.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00078.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00079.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00080.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00081.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00082.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00083.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00084.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00085.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00086.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00087.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00088.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00089.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00090.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00091.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00092.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00093.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00094.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00095.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00096.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00097.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00098.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00099.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00100.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00101.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00102.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00103.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00104.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00105.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00106.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00107.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00108.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00109.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00110.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00111.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00112.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00113.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00114.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00115.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00116.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00117.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00118.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00119.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00120.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00121.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00122.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00123.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00124.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00125.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00126.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00127.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00128.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00129.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00130.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00131.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00132.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00133.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00134.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00135.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00136.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00137.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00138.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00139.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00140.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00141.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00142.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00143.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00144.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00145.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00146.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00147.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00148.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00149.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00150.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00151.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00152.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00153.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00154.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00155.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00156.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00157.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00158.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00159.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00160.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00161.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00162.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/
svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00585.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00586.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00587.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00588.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00589.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00590.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00591.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00592.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00593.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00594.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00595.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00596.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00597.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00598.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00599.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00600.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00601.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00602.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00603.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00604.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00605.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00606.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00607.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00608.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00609.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00610.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00611.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00612.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00613.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/00614.svg: bad transparency mask
# ...
# Error processing ../datasets/circles_str/svg/04795.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04796.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04797.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04798.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04799.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04800.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04801.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04802.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04803.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04804.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04805.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04806.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04807.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04808.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04809.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04810.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04811.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04812.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04813.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04814.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04815.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04816.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04817.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04818.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04819.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04820.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04821.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04822.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04823.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04824.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04825.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04826.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04827.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04828.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04829.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04830.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04831.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04832.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04833.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04834.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04835.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04836.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04837.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04838.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04839.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04840.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04841.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04842.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04843.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04844.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04845.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04846.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04847.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04848.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04849.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04850.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04851.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04852.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04853.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04854.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04855.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04856.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04857.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04858.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04859.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04860.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04861.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04862.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04863.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04864.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04865.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04866.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04867.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04868.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04869.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04870.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04871.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04872.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04873.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04874.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04875.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04876.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04877.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04878.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04879.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04880.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04881.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04882.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04883.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04884.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04885.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04886.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04887.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04888.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04889.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04890.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04891.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04892.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04893.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04894.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04895.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04896.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04897.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04898.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04899.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04900.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04901.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04902.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04903.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04904.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04905.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04906.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04907.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04908.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04909.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04910.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04911.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04912.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04913.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04914.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04915.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04916.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04917.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04918.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04919.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04920.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04921.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04922.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04923.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04924.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04925.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04926.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04927.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04928.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04929.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04930.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04931.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04932.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04933.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04934.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04935.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04936.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04937.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04938.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04939.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04940.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04941.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04942.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04943.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04944.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04945.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04946.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04947.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04948.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04949.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04950.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04951.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04952.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04953.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04954.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04955.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04956.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04957.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04958.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04959.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04960.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04961.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04962.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04963.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04964.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04965.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04966.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04967.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04968.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04969.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04970.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04971.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04972.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04973.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04974.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04975.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04976.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04977.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04978.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04979.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04980.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04981.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04982.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04983.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04984.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04985.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04986.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04987.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04988.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04989.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04990.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04991.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04992.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04993.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04994.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04995.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04996.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04997.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04998.svg: bad transparency mask
# Error processing ../datasets/circles_str/svg/04999.svg: bad transparency mask

# %%
import os
from PIL import Image
import numpy as np

def compare_images(img1_path, img2_path):
    with Image.open(img1_path) as img1, Image.open(img2_path) as img2:
        # Resize images to the same size
        img1 = img1.resize((224, 224))
        img2 = img2.resize((224, 224))
        
        arr1 = np.array(img1)
        arr2 = np.array(img2)
        difference = np.abs(arr1.astype(np.float32) - arr2.astype(np.float32))
        mse = np.mean(difference ** 2)
        max_pixel_value = 255.0
        percent_difference = (mse / (max_pixel_value ** 2)) * 100
        
        return percent_difference <= 15.0
    
def compare_image_folders(folder1, folder2, num_images=5000):
    equal = not_equal = 0
    for i in range(num_images):
        img1_path = os.path.join(folder1, f'{i:05d}.png')
        img2_path = os.path.join(folder2, f'{i:05d}.png')
        
        if os.path.exists(img1_path) and os.path.exists(img2_path):
            if compare_images(img1_path, img2_path):
                equal += 1
            else:
                not_equal += 1
        else:
            print(f'One of the images {i:05d} is missing.')
    
    total = equal + not_equal
    print(f"Matches: {equal} images")
    print(f"Mismatches: {not_equal} images")
    if total > 0:
        print(f"Match percentage: {equal / total * 100:.2f}%")
    else:
        print("No images to compare.")
# Paths
svg_folder = '../datasets/circles/svg/'
png_folder = '../datasets/circles/pngg/'

# Compare images
compare_image_folders('../datasets/circles/png/', png_folder)
# Out:
# Matches: 2806 images
# Mismatches: 2194 images
# Match percentage: 56.12%
